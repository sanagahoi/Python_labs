# %% [markdown]
# # Volcano Eruptions
#
# Which volcanoes have experienced the longest eruptions?
#
# The dataset `volcanic-eruptions.csv` includes the start and end dates for all volcanic eruptions since 1800, along with each volcano's identification number. For eruptions that are still ongoing as of December 2024, the end date is recorded as December 2024.
#
# This dataset excludes any eruptive pauses shorter than three months. If an eruption resumes after more than three months of inactivity, it is classified as a new eruption.
#
# Note: Volcano Yasur in Vanuatu is not included in this list due to the absence of a clear start date.

# %%
# FOR GOOGLE COLAB ONLY.
# Uncomment and run the code below. A dialog will appear to upload files.
# Upload 'volcanic-eruptions.csv' and 'volcano-list.csv'.

# from google.colab import files
# uploaded = files.upload()

# %%
import pandas as pd
import matplotlib.pyplot as plt

eruptions = pd.read_csv('volcanic-eruptions.csv')
eruptions.head(3)
# Out:
#    volcano_id start_date end_date
# 0      211020    07-1913  04-1944
# 1      211020    02-1864  11-1868
# 2      211020    12-1854  05-1855

# %% [markdown]
# ### Additional dataset
#
# The dataset `volcano-list.csv` provides detailed information about each volcano, including its name, country, latitude, longitude, and type.

# %%
volcanoes = pd.read_csv('volcano-list.csv')
volcanoes.head(3)
# Out:
#    volcano_id               volcano_name  country      volcanic_region_group  \
# 0      210010  West Eifel Volcanic Field  Germany  European Volcanic Regions
# 1      210020            Chaine des Puys   France  European Volcanic Regions
# 2      210030        Olot Volcanic Field    Spain  European Volcanic Regions
#
#                       volcanic_region volcano_landform primary_volcano_type  \
# 0  Central European Volcanic Province          Cluster       Volcanic field
# 1  Western European Volcanic Province          Cluster         Lava dome(s)
# 2  Western European Volcanic Province          Cluster       Volcanic field
#
#    activity_evidence last_known_eruption  latitude  longitude  elevation_m  \
# 0     Eruption Dated            8300 BCE    50.170      6.850          600
# 1     Eruption Dated            4040 BCE    45.786      2.981         1464
# 2  Evidence Credible             Unknown    42.170      2.530          893
#
#                           tectonic_setting                dominant_rock_type
# 0   Rift zone / Continental crust (>25 km)                           Foidite
# 1   Rift zone / Continental crust (>25 km)             Basalt / Picro-Basalt
# 2  Intraplate / Continental crust (>25 km)  Trachybasalt / Tephrite Basanite

# %% [markdown]
# ### Project Ideas:
#
# - Find the volcanoes that were erupting as of Dec 2024.
#
# - Find the volcanoes that have had the longest volcanic eruptions.
#
# Hints:
# - Use `pd.to_datetime`.
#
# - Merge the volcanoes dataframe into eruptions.
#
# - Before the merge, reduce the dataframes to the columns of interest.
#
# - Use `df.sort_values`.

# %%
eruptions['start_date'] = pd.to_datetime(eruptions['start_date'])
eruptions['end_date'] = pd.to_datetime(eruptions['end_date'])
eruptions['duration'] = (eruptions['end_date'] - eruptions['start_date']).dt.days
eruptions[eruptions['duration'] ==eruptions['duration'].max()]
# Out:
#       volcano_id start_date   end_date  duration
# 2932      342030 1922-06-01 2024-12-01     37439

# %%
df = pd.merge(eruptions, volcanoes, on='volcano_id', how='left')

# %%
# longest eruptions
df[df['duration'] ==df['duration'].max()]
# Out:
#       volcano_id start_date   end_date  duration volcano_name    country  \
# 2932      342030 1922-06-01 2024-12-01     37439  Santa Maria  Guatemala
#
#                           volcanic_region_group               volcanic_region  \
# 2932  Middle America-Caribbean Volcanic Regions  Central America Volcanic Arc
#
#      volcano_landform primary_volcano_type  activity_evidence  \
# 2932        Composite        Stratovolcano  Eruption Observed
#
#      last_known_eruption  latitude  longitude  elevation_m  \
# 2932             2024 CE    14.757    -91.552         3745
#
#                                   tectonic_setting dominant_rock_type
# 2932  Subduction zone / Continental crust (>25 km)             Dacite

# %%
# Find the volcanoes that were erupting as of Dec 2024

df[df['start_date'].dt.month ==12]
# Out:
#       volcano_id start_date   end_date  duration           volcano_name  \
# 2         211020 1854-12-01 1855-05-01       151               Vesuvius
# 3         211020 1855-12-01 1861-12-01      2192               Vesuvius
# 6         211020 1875-12-01 1906-04-01     11078               Vesuvius
# 8         211020 1870-12-01 1872-04-01       487               Vesuvius
# 24        211060 2001-12-01 2003-11-01       700                   Etna
# ...          ...        ...        ...       ...                    ...
# 3674      373080 1975-12-01 1975-12-01         0                 Krafla
# 3680      373100 1867-12-01 1868-01-01        31  Tjornes Fracture Zone
# 3708      390020 1972-12-01 2024-12-01     18993                 Erebus
# 3711      390030 1967-12-01 1967-12-01         0       Deception Island
# 3715      390080 1936-12-01 1937-01-01        31         Bristol Island
#
#              country              volcanic_region_group  \
# 2              Italy          European Volcanic Regions
# 3              Italy          European Volcanic Regions
# 6              Italy          European Volcanic Regions
# 8              Italy          European Volcanic Regions
# 24             Italy          European Volcanic Regions
# ...              ...                                ...
# 3674         Iceland    Atlantic Ocean Volcanic Regions
# 3680         Iceland    Atlantic Ocean Volcanic Regions
# 3708      Antarctica  Antarctic-Scotia Volcanic Regions
# 3711      Antarctica  Antarctic-Scotia Volcanic Regions
# 3715  United Kingdom  Antarctic-Scotia Volcanic Regions
#
#                                  volcanic_region volcano_landform  \
# 2           Italian Peninsula Volcanic Provinces        Composite
# 3           Italian Peninsula Volcanic Provinces        Composite
# 6           Italian Peninsula Volcanic Provinces        Composite
# 8           Italian Peninsula Volcanic Provinces        Composite
# 24                      Sicily Volcanic Province        Composite
# ...                                          ...              ...
# 3674  Iceland Neovolcanic Rift Volcanic Province          Cluster
# 3680              Arctic Ridge Volcanic Province          Cluster
# 3708                   McMurdo Volcanic Province        Composite
# 3711                South Shetlands Volcanic Arc          Caldera
# 3715                 South Sandwich Volcanic Arc        Composite
#
#      primary_volcano_type  activity_evidence last_known_eruption  latitude  \
# 2           Stratovolcano  Eruption Observed             1944 CE   40.8210
# 3           Stratovolcano  Eruption Observed             1944 CE   40.8210
# 6           Stratovolcano  Eruption Observed             1944 CE   40.8210
# 8           Stratovolcano  Eruption Observed             1944 CE   40.8210
# 24      Stratovolcano(es)  Eruption Observed             2024 CE   37.7480
# ...                   ...                ...                 ...       ...
# 3674              Caldera  Eruption Observed             1984 CE   65.7150
# 3680         Fissure vent  Eruption Observed             1868 CE   66.3090
# 3708        Stratovolcano  Eruption Observed             2024 CE  -77.5300
# 3711              Caldera  Eruption Observed             1970 CE  -62.9567
# 3715        Stratovolcano  Eruption Observed             2016 CE  -59.0170
#
#       longitude  elevation_m                              tectonic_setting  \
# 2       14.4260         1281  Subduction zone / Continental crust (>25 km)
# 3       14.4260         1281  Subduction zone / Continental crust (>25 km)
# 6       14.4260         1281  Subduction zone / Continental crust (>25 km)
# 8       14.4260         1281  Subduction zone / Continental crust (>25 km)
# 24      14.9990         3357  Subduction zone / Continental crust (>25 km)
# ...         ...          ...                                           ...
# 3674   -16.7280          800           Rift zone / Oceanic crust (< 15 km)
# 3680   -17.1180          -75           Rift zone / Oceanic crust (< 15 km)
# 3708   167.1700         3794       Intraplate / Continental crust (>25 km)
# 3711   -60.6367          602       Intraplate / Continental crust (>25 km)
# 3715   -26.5330         1100     Subduction zone / Oceanic crust (< 15 km)
#
#                       dominant_rock_type
# 2     Phono-tephrite /  Tephri-phonolite
# 3     Phono-tephrite /  Tephri-phonolite
# 6     Phono-tephrite /  Tephri-phonolite
# 8     Phono-tephrite /  Tephri-phonolite
# 24      Trachybasalt / Tephrite Basanite
# ...                                  ...
# 3674               Basalt / Picro-Basalt
# 3680               Basalt / Picro-Basalt
# 3708                           Phonolite
# 3711               Basalt / Picro-Basalt
# 3715               Basalt / Picro-Basalt
#
# [291 rows x 17 columns]

# %%
df.sort_values(by='duration', ascending=False).head(1)
# Out:
#       volcano_id start_date   end_date  duration volcano_name    country  \
# 2932      342030 1922-06-01 2024-12-01     37439  Santa Maria  Guatemala
#
#                           volcanic_region_group               volcanic_region  \
# 2932  Middle America-Caribbean Volcanic Regions  Central America Volcanic Arc
#
#      volcano_landform primary_volcano_type  activity_evidence  \
# 2932        Composite        Stratovolcano  Eruption Observed
#
#      last_known_eruption  latitude  longitude  elevation_m  \
# 2932             2024 CE    14.757    -91.552         3745
#
#                                   tectonic_setting dominant_rock_type
# 2932  Subduction zone / Continental crust (>25 km)             Dacite
